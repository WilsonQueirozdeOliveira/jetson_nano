# %%
from time import sleep
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from pid_lib import pid
pid = pid(output=0, setpoint=10, feedback=0, 
          Kp=0.1, Ki=10, Kd=0.001, sample_time=0.01)
x = []
y = []
count = 0
output = 0 # sensor from output
while not (count>200):
    feedback = output # sensor from output
    output = pid.pid_update_(feedback=feedback,setpoint=10,
                               sample_time=0.01)
    #print('output=', output)
    y.append(output)
    x.append(count)
    count += 1
feedback = 0
#print(x,y)
plt.plot(x, y)
